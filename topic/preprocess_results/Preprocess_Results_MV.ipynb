# %% [markdown]
# # Process the results of LLM training methods

# %% [markdown]
# ### Import libraries and install the embedding model

# %%
# !pip install sentence-transformers

# %%
import os
import re
import json
import pandas as pd
import numpy as np
from collections import defaultdict, Counter
from sentence_transformers import SentenceTransformer, util

# %% [markdown]
# ### File paths to preprocess

# %%
# List of files to preprocess
file_paths = [
    'results/CoT_Zero_shot_results_2024-05-16_14-16-01.txt',
    'results/CoT_Zero_shot_results_2024-05-16_14-53-06.txt',
    'results/CoT_Zero_shot_results_2024-05-16_15-29-13.txt',
    'results/CoT_Zero_shot_results_2024-05-16_15-57-48.txt',
    'results/CoT_Zero_shot_results_2024-05-16_16-28-12.txt',
    'results/CoT_Zero_shot_results_2024-05-16_17-01-39.txt',
    'results/CoT_Zero_shot_results_2024-05-16_17-34-21.txt',
    'results/CoT_Zero_shot_results_2024-05-16_18-22-13.txt',
    'results/CoT_Zero_shot_results_2024-05-16_19-38-30.txt',
    'results/CoT_Zero_shot_results_2024-05-16_20-06-44.txt'
]

# The training method
method = "CoT_Zero_shot"

# %% [markdown]
# ### Data preprocessing

# %%
# Mapping dictionary for topics
topic_mapping = {
    "municipality and residents engagement in the energy sector": 1,
    "residents engagement": 1,
    "municipality engagement": 1,
    "residents engagement in the energy sector": 1,
    "municipality engagement in the energy sector": 1,
    "energy storage and supplying energy in the netherlands": 2,
    "energy storage and supply in the netherlands": 2,
    "energy storage in the netherlands": 2,
    "supplying energy in the netherlands": 2,
    "energy storage": 2,
    "wind and solar energy": 3,
    "solar energy": 3,
    "wind energy": 3,
    "market determination dynamics": 4,
    "market dynamics": 4,
    "market determination": 4,
    "landscapes and windmills tourism": 5,
    "landscapes and windmills": 5,
    "hydrogen energy pipeline networks": 6,
    "hydrogen energy pipeline": 6
}

# Load the Sentence Transformer model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Pre-compute embeddings for topic mapping keys
topic_embeddings = {topic: model.encode(topic, convert_to_tensor=True) for topic in topic_mapping.keys()}

def is_valid_topic(topic):
    """
    Check if a topic string is valid (not empty) when removing special characters

    Args:
        topic (str): the topic string
    Returns:
        bool : True if topic is valid, False otherwise

    """
    # Remove special characters and check if the resulting string is empty
    return re.sub(r'[^A-Za-z0-9]+', '', topic).strip() != ''

def process_topics(topics):
    """
    Map the topic list to the original list of topics
    The mapping is done using Sentence-Transformers embedding model (if the topic is not in 'topic_mapping')

    Args:
        topics (list): the list of topics to be preprocessed
    Returns:
        topic_numbers (list) : list of indices indicating the mapping of the topics to the original list

    """
    # Extract numbers and topic strings from the topics
    topic_numbers = set()
    threshold = 0.70  # Cosine similarity threshold for similarity

    if isinstance(topics, int):
        topic_numbers.add(topics)
    elif isinstance(topics, list):
        for topic in topics:
            if isinstance(topic, int):
                topic_numbers.add(topic)
            elif topic.isdigit():
                topic_numbers.add(int(topic))
            else:
                topic_lower = topic.lower().strip()  # Convert to lowercase
                if is_valid_topic(topic_lower):
                    topic_embedding = model.encode(topic_lower, convert_to_tensor=True)
                    # Perform cosine similarity matching
                    similarities = {key: util.pytorch_cos_sim(topic_embedding, emb).item() for key, emb in topic_embeddings.items()}
                    matched_topic, score = max(similarities.items(), key=lambda x: x[1])
                    if score >= threshold:
                        topic_numbers.add(topic_mapping[matched_topic])
                    else:
                        print(f"Low match score for topic '{topic}': {score}")
                else:
                    print(f"Invalid topic '{topic}'")
    elif isinstance(topics, str):
        topic_lower = topics.lower().strip()  # Convert to lowercase
        if is_valid_topic(topic_lower):
            topic_embedding = model.encode(topic_lower, convert_to_tensor=True)
            # Perform cosine similarity matching
            similarities = {key: util.pytorch_cos_sim(topic_embedding, emb).item() for key, emb in topic_embeddings.items()}
            matched_topic, score = max(similarities.items(), key=lambda x: x[1])
            if score >= threshold:
                topic_numbers.add(topic_mapping[matched_topic])
            else:
                print(f"Low match score for topic '{topics}': {score}")
        else:
            print(f"Invalid topic '{topics}'")

    # Remove None values and sort the topics
    topic_numbers = sorted([t for t in topic_numbers if t is not None])
    return topic_numbers

def preprocess_file(file_path):
    """
    Preprocess file with results to map the topics to the original topics list
    Writes the preprocessed file in a new file with the name 'file_path_processed'  in the folder 'results'
    Args:
        file_path (str): the file path to preprocess

    """
    processed_lines = []

    print(f"Processing file: {file_path}")

    with open(file_path, 'r', encoding='latin1') as file:
        lines = file.readlines()
        i = 0
        while i < len(lines):
            line = lines[i].strip()
            if line.lower().startswith("text:"):
                text_line = line
                print(f"Found text: {text_line}")
                i += 1
                while i < len(lines) and not lines[i].strip().lower().startswith("text:"):
                    line = lines[i].strip()
                    if re.search(r"\{'Topics':(.+?)\}", line):
                        match = re.search(r"\{'Topics':(.+?)\}", line)
                        topics_str = match.group(1).strip()
                    elif re.search(r"\['Topics':(.+?)\]", line):
                        match = re.search(r"\['Topics':(.+?)\]", line)
                        topics_str = match.group(1).strip()
                    else:
                        i += 1
                        continue

                    print(f"Found topics string: {topics_str}")

                    try:
                        topics = json.loads(topics_str.replace("'", "\""))
                        if isinstance(topics, str):
                            topics = [topics]
                        elif isinstance(topics, dict):
                            topics = [topics]
                    except json.JSONDecodeError:
                        topics = re.findall(r"'(.*?)'", topics_str) + re.findall(r"(\d+)", topics_str)

                    if not topics:
                        topics = topics_str.split(', ')

                    print(f"Extracted topics: {topics}")
                    processed_topics = process_topics(topics)
                    print(f"Processed topics: {processed_topics}")
                    processed_lines.append(f"{text_line}\n")
                    processed_lines.append(f"{{'Topics': {', '.join(map(str, processed_topics))}}}\n")
                    processed_lines.append("\n")
                    break
            elif line.strip().startswith("['Topics") or line.strip().startswith("Topics") or line.strip().startswith("'Topics"):
                topics_str = line.split(":", 1)[1].strip().strip('[]')
                print(f"Found topics string: {topics_str}")

                try:
                    topics = json.loads(topics_str.replace("'", "\""))
                    if isinstance(topics, str):
                        topics = [topics]
                    elif isinstance(topics, dict):
                        topics = [topics]
                except json.JSONDecodeError:
                    topics = re.findall(r"'(.*?)'", topics_str) + re.findall(r"(\d+)", topics_str)

                if not topics:
                    topics = topics_str.split(', ')

                print(f"Extracted topics: {topics}")
                processed_topics = process_topics(topics)
                print(f"Processed topics: {processed_topics}")
                processed_lines.append(f"{{'Topics': {', '.join(map(str, processed_topics))}}}\n")
                processed_lines.append("\n")
            i += 1
    # Save the processed file to the processed_data directory
    output_path = os.path.join(processed_data_dir, os.path.basename(file_path).replace(".txt", "_processed.txt"))
    with open(output_path, 'w', encoding='latin1') as output_file:
        output_file.writelines(processed_lines)
    print(f"Finished processing file: {file_path}")
    print(f"Processed file saved to: {output_path}\n")
# Out:
# C:\Users\marcu\AppData\Local\Programs\Python\Python312\Lib\site-packages\sentence_transformers\cross_encoder\CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# The installed version of bitsandbytes was compiled without GPU support. 8-bit optimizers, 8-bit multiplication, and GPU quantization are unavailable.
# C:\Users\marcu\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# Processing file: results/CoT_Zero_shot_results_2024-05-16_14-16-01.txt
# Found text: Text: Residents are needed. It's also a lot of fun to get involved. However, there are quick choices of principle that exclude other solutions. Very valuable on a small scale (including mienskip) and that certainly in combination with climate and reuse. Local initiatives can also lead to fragmentation while electricity must always be available, and inefficiencies.
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I assign points to both "The municipality takes the lead and unburdens" and to "Residents do it themselves". This seems contradictory, and it is. Nevertheless, I also think the residents' own initiative is important. For support, for social cohesion, but also for management. A local cooperative will be able to supply energy significantly cheaper than a commercial party. I have a hesitation about sustainability. People move, neighborhoods change, engagement can become less. To what extent can a cooperative guarantee that everyone always has access to energy?
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Given the installation of wind turbines in IJsselmeer, it would increase the effectiveness of this form of energy generation if efficient storage can take place.
# Found topics string: 'Energy storage', 'Wind and solar energy'
# Extracted topics: ['Energy storage', 'Wind and solar energy']
# Processed topics: [2, 3]
# Found text: Text: Coordination and distribution over the entire municipality As an independent party, the municipality can make the choice between the interests of individuals and residential communities
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I would like to see a large field of solar panels, worn by the inhabitants themselves, paid for by the inhabitants themselves, the moment a resident leaves for the area he should be able to sell his part back, new residents should also be able to buy a part. In this way, you as a municipality become self-sufficient while it is affordable for the vast majority of residents. Residents who would not be able to participate financially, must be able to use the solar energy, as they currently purchase electricity from their supplier.
# Found topics string: [1, 2, 3]
# Extracted topics: [1, 2, 3]
# Processed topics: [1, 2, 3]
# Found text: Text: With more storage, more energy can perhaps be stored at peak times that can be used at another time. (i.e. ultimately generate less in total capacity)
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics in The Netherlands'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics in The Netherlands']
# Processed topics: [2, 4]
# Found text: Text: Here I have given 10 points. A fairly large wind farm is already coming near me, between Zurich and Witmarsum. I think that's enough for Sï¿½dwest-Fryslï¿½n. The idea of making Sï¿½dwest-Fryslï¿½n the supplier of the Netherlands seems to me to be a bad idea. We have wind here, so let's limit ourselves to windmills. Then other parts of the country can invest in large-scale solar parks with less wind. Please share the burden.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# Found topics string: 1, 2, 3, 4, 5, 6
# Extracted topics: ['1', '2', '3', '4', '5', '6']
# Processed topics: [1, 2, 3, 4, 5, 6]
# Found text: Text: With this proposal it is of course difficult because you have to have so many enerie generators. So I actually think this is a difficult statement, but I think the idea of helping certain parts of the Netherlands through sustainable energy is a good idea that needs to be used more.
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [2, 3, 4]
# Found text: Text: We have the space in the countryside to generate more than we consume. We owe our entire polder country to wind energy. The wind is nice here. Let's do more than our part here. They are opportunities. A new landscape is not necessarily a bad landscape. But let the profits descend locally. People have been given a little more to spend, e.g. for sustainable products, which are now slightly more expensive. Living and building land is far too expensive in Ned. Too much money is being knocked out of people's pockets for housing. Because of these high costs, the willingness to invest in sustainability is lower than in the surrounding countries.
# Found topics string: [1, 2, 3]
# Extracted topics: [1, 2, 3]
# Processed topics: [1, 2, 3]
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'.
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [2, 3]
# Found text: Text: The (living) situation is different for everyone. However, anyone who is willing to contribute to it should be encouraged.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: I don't think you can leave this entirely to the inhabitants. But in my view, private initiatives should be possible.
# Found topics string: 'Municipality and residents engagement', 'Energy storage and supplying energy', 'Wind and solar energy', 'Market Determination Dynamics', 'Tourism related to windmills landscapes', 'Hydrogen energy pipeline networks'
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supplying energy', 'Wind and solar energy', 'Market Determination Dynamics', 'Tourism related to windmills landscapes', 'Hydrogen energy pipeline networks']
# Processed topics: [1, 2, 3, 4, 5, 6]
# Found text: Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# Found topics string: 'Market dynamics', 'Sustainability', 'Profitability'
# Extracted topics: ['Market dynamics', 'Sustainability', 'Profitability']
# Low match score for topic 'Sustainability': 0.41233837604522705
# Low match score for topic 'Profitability': 0.4345889091491699
# Processed topics: [4]
# Found text: Text: Residents can take care of solar panels, heat pumps, etc. POSSIBLY WITH THE HELP OF GOOD FINANCING PROGRAMS.
# Found topics string: 'Energy and sustainability', 'Financing and economics', 'Infrastructure and planning', 'Technology and innovation', 'Tourism and leisure', 'Transportation and logistics'
# Extracted topics: ['Energy and sustainability', 'Financing and economics', 'Infrastructure and planning', 'Technology and innovation', 'Tourism and leisure', 'Transportation and logistics']
# Low match score for topic 'Energy and sustainability': 0.6493313908576965
# Low match score for topic 'Financing and economics': 0.47813352942466736
# Low match score for topic 'Infrastructure and planning': 0.4838080406188965
# Low match score for topic 'Technology and innovation': 0.3246895968914032
# Low match score for topic 'Tourism and leisure': 0.6274775266647339
# Low match score for topic 'Transportation and logistics': 0.4720277786254883
# Processed topics: []
# Found text: Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# Found topics string: 'Energy sector and supply', 'Renewable energy sources', 'Local government engagement', 'Tourism'
# Extracted topics: ['Energy sector and supply', 'Renewable energy sources', 'Local government engagement', 'Tourism']
# Low match score for topic 'Energy sector and supply': 0.6433672904968262
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Low match score for topic 'Tourism': 0.5735376477241516
# Processed topics: [1]
# Found text: Text: I don't see anything in this. The landscape is helped to the sodemieter while Sï¿½dwest-Fryslï¿½n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# Found topics string: [1, 2, 3, 5]
# Extracted topics: [1, 2, 3, 5]
# Processed topics: [1, 2, 3, 5]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: 'Municipality and residents engagement', 'Energy storage and supplying', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supplying', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: 'Energy storage and supply in The Netherlands', 'Transition from one energy source to another', 'Landscape tourism'
# Extracted topics: ['Energy storage and supply in The Netherlands', 'Transition from one energy source to another', 'Landscape tourism']
# Low match score for topic 'Transition from one energy source to another': 0.5865478515625
# Low match score for topic 'Landscape tourism': 0.6678527593612671
# Processed topics: [2]
# Found text: Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# Found topics string: 'Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# Found topics string: 'Centralization of energy supply', 'Green energy', 'Reliability of energy supply'
# Extracted topics: ['Centralization of energy supply', 'Green energy', 'Reliability of energy supply']
# Low match score for topic 'Centralization of energy supply': 0.6549086570739746
# Low match score for topic 'Green energy': 0.5961170792579651
# Low match score for topic 'Reliability of energy supply': 0.5863624811172485
# Processed topics: []
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: [2, 1, 5]
# Extracted topics: [2, 1, 5]
# Processed topics: [1, 2, 5]
# Found text: Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: People want to be involved in these kinds of decisions. We want to choose how we make it more sustainable.
# Found topics string: ['Residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: Invention and innovation, Energy supply and storage, Market dynamics
# Extracted topics: ['Invention and innovation', 'Energy supply and storage', 'Market dynamics']
# Low match score for topic 'Invention and innovation': 0.26381784677505493
# Processed topics: [2, 4]
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: 'Municipality and residents engagement in the energy sector'
# Extracted topics: ['Municipality and residents engagement in the energy sector']
# Processed topics: [1]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'Energy supply and distribution', 'Residential areas and energy use', 'Renewable energy sources'
# Extracted topics: ['Energy supply and distribution', 'Residential areas and energy use', 'Renewable energy sources']
# Low match score for topic 'Energy supply and distribution': 0.6698513031005859
# Low match score for topic 'Residential areas and energy use': 0.6928822994232178
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: []
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: direction from the public party (steering on the fair distribution of benefits and burdens) and ensuring the quality of the landscape
# Found topics string: 'Energy storage', 'Wind and solar energy', 'Residents' engagement in the energy sector'
# Extracted topics: ['Energy storage', 'Wind and solar energy', 'Residents']
# Processed topics: [1, 2, 3]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: 'Municipality and residents engagement', 'Energy storage and supplying', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supplying', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# Found text: Text: If the citizens of the municipality see a leading role in this, a pioneering role to enable sustainable energy generation, then this is certainly a consideration. But here too, the citizens themselves should really be 100% behind it. There is a danger with this option that the main focus of this is on the revenue model, while, in my opinion, it is really mainly about involving citizens in the generation of sustainable energy and consciously working on this.
# Found topics string: Municipality and residents engagement in the energy sector, Sustainable energy sources (wind and solar energy), Revenue model dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Sustainable energy sources (wind and solar energy)', 'Revenue model dynamics']
# Processed topics: [1, 3, 4]
# Found text: Text: Is think this is easiest solution and probably the cheapest? However, this often causes a disruption of the landscape / environment (large fields with solar panels, for example)
# Found topics string: Energy storage and supplying energy in The Netherlands, Wind and solar energy, Landscapes and windmills tourism
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Landscapes and windmills tourism']
# Processed topics: [2, 3, 5]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found text: Text: In this way, nature is affected in as few places as possible and you have the energy generators all together.
# Found topics string: 'Energy generation and nature conservation', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy generation and nature conservation', 'Wind and solar energy', 'Market Determination Dynamics']
# Low match score for topic 'Energy generation and nature conservation': 0.6055045127868652
# Processed topics: [3, 4]
# Found text: Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# Found topics string: 'Energy storage', 'Supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Energy storage', 'Supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [2, 3]
# Found text: Text: Here too, a positive effect on the labour market in the region. The impact on quality of life and tourism is an important precondition for this.
# Found topics string: Renewable Energy Sources, Labor Market and Employment Impacts, Quality of Life and Tourism
# Extracted topics: ['Renewable Energy Sources', 'Labor Market and Employment Impacts', 'Quality of Life and Tourism']
# Low match score for topic 'Renewable Energy Sources': 0.6709546446800232
# Low match score for topic 'Labor Market and Employment Impacts': 0.4866357147693634
# Low match score for topic 'Quality of Life and Tourism': 0.4839831590652466
# Processed topics: []
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: 'Energy storage', 'Network infrastructure', 'Renewable energy sources'
# Extracted topics: ['Energy storage', 'Network infrastructure', 'Renewable energy sources']
# Low match score for topic 'Network infrastructure': 0.36198103427886963
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [2]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: municipality and residents engagement in the energy sector, energy storage and supplying energy in The Netherlands, wind and solar energy
# Extracted topics: ['municipality and residents engagement in the energy sector', 'energy storage and supplying energy in The Netherlands', 'wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: [Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy]
# Extracted topics: ['[Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy]']
# Processed topics: [1, 2, 3]
# Found text: Text: The municipality determines the rules and has the subsidies to make citizens aware and motivate. But will also have to follow the provincial/national guidelines.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: 'Energy storage', 'Local infrastructure (housing and recycling)', 'Recycling of batteries over years'
# Extracted topics: ['Energy storage', 'Local infrastructure (housing and recycling)', 'Recycling of batteries over years']
# Low match score for topic 'Local infrastructure (housing and recycling)': 0.500274658203125
# Low match score for topic 'Recycling of batteries over years': 0.44000476598739624
# Processed topics: [2]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Finished processing file: results/CoT_Zero_shot_results_2024-05-16_14-16-01.txt
# Processed file saved to: processed_data\CoT_Zero_shot_results_2024-05-16_14-16-01_processed.txt
#
# Processing file: results/CoT_Zero_shot_results_2024-05-16_14-53-06.txt
# Found text: Text: Residents are needed. It's also a lot of fun to get involved. However, there are quick choices of principle that exclude other solutions. Very valuable on a small scale (including mienskip) and that certainly in combination with climate and reuse. Local initiatives can also lead to fragmentation while electricity must always be available, and inefficiencies.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I assign points to both "The municipality takes the lead and unburdens" and to "Residents do it themselves". This seems contradictory, and it is. Nevertheless, I also think the residents' own initiative is important. For support, for social cohesion, but also for management. A local cooperative will be able to supply energy significantly cheaper than a commercial party. I have a hesitation about sustainability. People move, neighborhoods change, engagement can become less. To what extent can a cooperative guarantee that everyone always has access to energy?
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Given the installation of wind turbines in IJsselmeer, it would increase the effectiveness of this form of energy generation if efficient storage can take place.
# Found topics string: 'Wind energy', 'Energy storage', 'Dutch energy sector'
# Extracted topics: ['Wind energy', 'Energy storage', 'Dutch energy sector']
# Processed topics: [2, 3]
# Found text: Text: Coordination and distribution over the entire municipality As an independent party, the municipality can make the choice between the interests of individuals and residential communities
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: I would like to see a large field of solar panels, worn by the inhabitants themselves, paid for by the inhabitants themselves, the moment a resident leaves for the area he should be able to sell his part back, new residents should also be able to buy a part. In this way, you as a municipality become self-sufficient while it is affordable for the vast majority of residents. Residents who would not be able to participate financially, must be able to use the solar energy, as they currently purchase electricity from their supplier.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: With more storage, more energy can perhaps be stored at peak times that can be used at another time. (i.e. ultimately generate less in total capacity)
# Found topics string: 'Energy storage', 'Market Determination Dynamics', 'Peak times'
# Extracted topics: ['Energy storage', 'Market Determination Dynamics', 'Peak times']
# Low match score for topic 'Peak times': 0.20977911353111267
# Processed topics: [2, 4]
# Found text: Text: Here I have given 10 points. A fairly large wind farm is already coming near me, between Zurich and Witmarsum. I think that's enough for Sï¿½dwest-Fryslï¿½n. The idea of making Sï¿½dwest-Fryslï¿½n the supplier of the Netherlands seems to me to be a bad idea. We have wind here, so let's limit ourselves to windmills. Then other parts of the country can invest in large-scale solar parks with less wind. Please share the burden.
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Wind and solar energy', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2, 3]
# Found text: Text: With this proposal it is of course difficult because you have to have so many enerie generators. So I actually think this is a difficult statement, but I think the idea of helping certain parts of the Netherlands through sustainable energy is a good idea that needs to be used more.
# Found topics string: ['Energy Generation and Storage', 'Sustainable Energy for Certain Parts of the Netherlands', 'Other Energy-Related Topics']
# Extracted topics: ['Energy Generation and Storage', 'Sustainable Energy for Certain Parts of the Netherlands', 'Other Energy-Related Topics']
# Low match score for topic 'Other Energy-Related Topics': 0.6330060958862305
# Processed topics: [2]
# Found text: Text: We have the space in the countryside to generate more than we consume. We owe our entire polder country to wind energy. The wind is nice here. Let's do more than our part here. They are opportunities. A new landscape is not necessarily a bad landscape. But let the profits descend locally. People have been given a little more to spend, e.g. for sustainable products, which are now slightly more expensive. Living and building land is far too expensive in Ned. Too much money is being knocked out of people's pockets for housing. Because of these high costs, the willingness to invest in sustainability is lower than in the surrounding countries.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics']
# Processed topics: [1, 2, 4]
# Found text: Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# Found topics string: 'Wind and solar energy', 'Energy storage', None of the topics are applicable
# Extracted topics: ['Wind and solar energy', 'Energy storage']
# Processed topics: [2, 3]
# Found text: Text: The (living) situation is different for everyone. However, anyone who is willing to contribute to it should be encouraged.
# Found topics string: 1, 3, 6
# Extracted topics: ['1', '3', '6']
# Processed topics: [1, 3, 6]
# Found text: Text: I don't think you can leave this entirely to the inhabitants. But in my view, private initiatives should be possible.
# Found topics string: 1, 3, 6
# Extracted topics: ['1', '3', '6']
# Processed topics: [1, 3, 6]
# Found text: Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# Found topics string: ['Cooperation and partnership', 'Energy storage and supply', 'Renewable energy sources']
# Extracted topics: ['Cooperation and partnership', 'Energy storage and supply', 'Renewable energy sources']
# Low match score for topic 'Cooperation and partnership': 0.43678566813468933
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [2]
# Found text: Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# Found topics string: 'Market dynamics', 'Municipal administration and control', 'Sustainability and profitability'
# Extracted topics: ['Market dynamics', 'Municipal administration and control', 'Sustainability and profitability']
# Low match score for topic 'Municipal administration and control': 0.6124944686889648
# Low match score for topic 'Sustainability and profitability': 0.39980456233024597
# Processed topics: [4]
# Found text: Text: Residents can take care of solar panels, heat pumps, etc. POSSIBLY WITH THE HELP OF GOOD FINANCING PROGRAMS.
# Found topics string: ['Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# Found topics string: ['Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement', 'Energy storage and supply', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I don't see anything in this. The landscape is helped to the sodemieter while Sï¿½dwest-Fryslï¿½n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: ['Energy storage and supply in The Netherlands', 'Transition to nuclear energy', 'Residents' engagement in the energy sector']
# Extracted topics: ['Energy storage and supply in The Netherlands', 'Transition to nuclear energy', 'Residents']
# Low match score for topic 'Transition to nuclear energy': 0.474097341299057
# Processed topics: [1, 2]
# Found text: Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# Found topics string: ['Centralized control', 'Energy management in the Netherlands', 'Renewable energy sources']
# Extracted topics: ['Centralized control', 'Energy management in the Netherlands', 'Renewable energy sources']
# Low match score for topic 'Centralized control': 0.26153865456581116
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [2]
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: 3, 'Topic1': 'Wind and solar energy', 'Topic2': 'Energy storage', 'Topic3': 'Market Determination Dynamics'
# Extracted topics: ['Topic1', 'Wind and solar energy', 'Topic2', 'Energy storage', 'Topic3', 'Market Determination Dynamics', '3', '1', '2', '3']
# Low match score for topic 'Topic1': 0.2161533236503601
# Low match score for topic 'Topic2': 0.23669429123401642
# Low match score for topic 'Topic3': 0.2224419116973877
# Processed topics: [1, 2, 3, 4]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [2, 3, 4]
# Found text: Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# Found topics string: 'Energy supply and demand', 'Competition and collaboration', 'Technological innovation'
# Extracted topics: ['Energy supply and demand', 'Competition and collaboration', 'Technological innovation']
# Low match score for topic 'Energy supply and demand': 0.6527369022369385
# Low match score for topic 'Competition and collaboration': 0.41360342502593994
# Low match score for topic 'Technological innovation': 0.30307817459106445
# Processed topics: []
# Found text: Text: People want to be involved in these kinds of decisions. We want to choose how we make it more sustainable.
# Found topics string: ['Sustainability', 'Energy storage', 'Wind and solar energy']
# Extracted topics: ['Sustainability', 'Energy storage', 'Wind and solar energy']
# Low match score for topic 'Sustainability': 0.41233837604522705
# Processed topics: [2, 3]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: 'Energy storage', 'Wind and solar energy'
# Extracted topics: ['Energy storage', 'Wind and solar energy']
# Processed topics: [2, 3]
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: ['1. Government intervention in energy production and distribution', '2. Energy storage and supply in the Netherlands', '3. Renewable energy sources (wind and solar)']
# Extracted topics: ['1. Government intervention in energy production and distribution', '2. Energy storage and supply in the Netherlands', '3. Renewable energy sources (wind and solar)']
# Low match score for topic '1. Government intervention in energy production and distribution': 0.6036523580551147
# Processed topics: [2, 3]
# Found text: Text: direction from the public party (steering on the fair distribution of benefits and burdens) and ensuring the quality of the landscape
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: ['Earnings for municipality and Netherlands', 'Energy storage and supply in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Earnings for municipality and Netherlands', 'Energy storage and supply in The Netherlands', 'Wind and solar energy']
# Low match score for topic 'Earnings for municipality and Netherlands': 0.5131579637527466
# Processed topics: [2, 3]
# Found text: Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# Found topics string: ['Wind and solar energy', 'Energy storage and supplying energy in The Netherlands', 'Municipality and residents engagement in the energy sector']
# Extracted topics: ['Wind and solar energy', 'Energy storage and supplying energy in The Netherlands', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 2, 3]
# Found text: Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# Found topics string: ['Community engagement', 'Energy storage and supply', 'Wind and solar energy']
# Extracted topics: ['Community engagement', 'Energy storage and supply', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: If the citizens of the municipality see a leading role in this, a pioneering role to enable sustainable energy generation, then this is certainly a consideration. But here too, the citizens themselves should really be 100% behind it. There is a danger with this option that the main focus of this is on the revenue model, while, in my opinion, it is really mainly about involving citizens in the generation of sustainable energy and consciously working on this.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Is think this is easiest solution and probably the cheapest? However, this often causes a disruption of the landscape / environment (large fields with solar panels, for example)
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: Energy management and distribution, Renewable energy sources (wind and solar), Energy infrastructure and logistics (energy pipelines, etc.).
# Extracted topics: ['Energy management and distribution', 'Renewable energy sources (wind and solar)', 'Energy infrastructure and logistics (energy pipelines', 'etc.).']
# Low match score for topic 'Energy management and distribution': 0.687637209892273
# Low match score for topic 'etc.).': 0.18914256989955902
# Processed topics: [3, 6]
# ...
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Energy storage', 'Wind and solar energy'.
# Extracted topics: ['Energy storage', 'Wind and solar energy']
# Processed topics: [2, 3]
# Found text: Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# Found topics string: ['Energy competition and choice among consumers', 'Engagement of municipality and residents in energy sector', 'Energy storage and supply in The Netherlands']
# Extracted topics: ['Energy competition and choice among consumers', 'Engagement of municipality and residents in energy sector', 'Energy storage and supply in The Netherlands']
# Low match score for topic 'Energy competition and choice among consumers': 0.5062605142593384
# Processed topics: [1, 2]
# Found text: Text: People want to be involved in these kinds of decisions. We want to choose how we make it more sustainable.
# Found topics string: 'Energy sustainability', 'Community involvement in energy-related issues', 'Renewable energy sources'
# Extracted topics: ['Energy sustainability', 'Community involvement in energy-related issues', 'Renewable energy sources']
# Low match score for topic 'Energy sustainability': 0.6388252973556519
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [1]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: ['Invention and innovation', 'Energy supply and distribution', 'Renewable energy sources']
# Extracted topics: ['Invention and innovation', 'Energy supply and distribution', 'Renewable energy sources']
# Low match score for topic 'Invention and innovation': 0.26381784677505493
# Low match score for topic 'Energy supply and distribution': 0.6698513031005859
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: []
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: ['Energy sector engagement', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Energy sector engagement', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: 'Government intervention in energy sector', 'Energy storage and distribution', 'Renewable energy sources'
# Extracted topics: ['Government intervention in energy sector', 'Energy storage and distribution', 'Renewable energy sources']
# Low match score for topic 'Government intervention in energy sector': 0.6730400323867798
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [2]
# Found text: Text: direction from the public party (steering on the fair distribution of benefits and burdens) and ensuring the quality of the landscape
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [2, 3, 4]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [2, 3, 4]
# Found text: Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# Found topics string: Wind and solar energy, Energy storage, Municipality and residents engagement in the energy sector
# Extracted topics: ['Wind and solar energy', 'Energy storage', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 2, 3]
# Found text: Text: If the citizens of the municipality see a leading role in this, a pioneering role to enable sustainable energy generation, then this is certainly a consideration. But here too, the citizens themselves should really be 100% behind it. There is a danger with this option that the main focus of this is on the revenue model, while, in my opinion, it is really mainly about involving citizens in the generation of sustainable energy and consciously working on this.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Is think this is easiest solution and probably the cheapest? However, this often causes a disruption of the landscape / environment (large fields with solar panels, for example)
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'None of the topics are applicable'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Wind and solar energy', 'None of the topics are applicable']
# Low match score for topic 'None of the topics are applicable': 0.14679493010044098
# Processed topics: [2, 3]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: 'Energy storage', 'Wind and solar energy', 'Market Determination Dynamics'
# Extracted topics: ['Energy storage', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [2, 3, 4]
# Found text: Text: An energy cooperative such as the one in IJlst is a good example. No impact on the landscape. Small-scale and close to a business park. Excellent. Even better, of course, is that the roofs are first fully used. If this is not possible, search for double destinations and overhangs (good example, solar park Hemriksein in exit loop N31). Can't fit this against village or city centers (as for example in IJlst). The village mill is also possible, then this should be an existing mill that is scaled up (same mill, only more modern and therefore more MW). No new mills.
# Found topics string: 'Wind and solar energy', 'Energy storage', 'Residents engagement in the energy sector'
# Extracted topics: ['Wind and solar energy', 'Energy storage', 'Residents engagement in the energy sector']
# Processed topics: [1, 2, 3]
# Found text: Text: In this way, nature is affected in as few places as possible and you have the energy generators all together.
# Found topics string: 'Energy generation and distribution', 'Sustainability and environmental considerations', 'Infrastructure planning and management'
# Extracted topics: ['Energy generation and distribution', 'Sustainability and environmental considerations', 'Infrastructure planning and management']
# Low match score for topic 'Energy generation and distribution': 0.6305033564567566
# Low match score for topic 'Sustainability and environmental considerations': 0.5058112144470215
# Low match score for topic 'Infrastructure planning and management': 0.48911088705062866
# Processed topics: []
# Found text: Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# Found topics string: [2, 5, 4]
# Extracted topics: [2, 5, 4]
# Processed topics: [2, 4, 5]
# Found text: Text: Here too, a positive effect on the labour market in the region. The impact on quality of life and tourism is an important precondition for this.
# Found topics string: 1. Municipality and residents engagement in the energy sector, 2. Energy storage and supplying energy in The Netherlands, 3. Wind and solar energy
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: Energy storage, Wind and solar energy, Government decision-making, Landscape protection, Tourism, Hydrogen energy pipeline networks
# Extracted topics: ['Energy storage', 'Wind and solar energy', 'Government decision-making', 'Landscape protection', 'Tourism', 'Hydrogen energy pipeline networks']
# Low match score for topic 'Government decision-making': 0.4732367992401123
# Low match score for topic 'Landscape protection': 0.4221375584602356
# Low match score for topic 'Tourism': 0.5735376477241516
# Processed topics: [2, 3, 6]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: 'Energy storage', 'Infrastructure', 'Renewable energy sources'
# Extracted topics: ['Energy storage', 'Infrastructure', 'Renewable energy sources']
# Low match score for topic 'Infrastructure': 0.4190517067909241
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [2]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: 1, 2, 3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: The municipality determines the rules and has the subsidies to make citizens aware and motivate. But will also have to follow the provincial/national guidelines.
# Found topics string: Municipality and residents engagement in the energy sector, Energy infrastructure and supply, Renewable energy sources
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy infrastructure and supply', 'Renewable energy sources']
# Low match score for topic 'Energy infrastructure and supply': 0.6728256344795227
# Low match score for topic 'Renewable energy sources': 0.6709546446800232
# Processed topics: [1]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: 'Energy storage and supplying energy in The Netherlands', 'Recycling of batteries over years', 'Wind and solar energy'
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Recycling of batteries over years', 'Wind and solar energy']
# Low match score for topic 'Recycling of batteries over years': 0.44000476598739624
# Processed topics: [2, 3]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Finished processing file: results/CoT_Zero_shot_results_2024-05-16_20-06-44.txt
# Processed file saved to: processed_data\CoT_Zero_shot_results_2024-05-16_20-06-44_processed.txt
#
# Processing completed. Processed files are saved in the 'processed_data' folder.

# %%
# Ensure the processed_data directory exists
processed_data_dir = 'processed_data'
os.makedirs(processed_data_dir, exist_ok=True)

# Process each file
for file_path in file_paths:
    preprocess_file(file_path)

processed_file_paths = [os.path.join(processed_data_dir, os.path.basename(file_path).replace(".txt", "_processed.txt")) for file_path in file_paths]

print("Processing completed. Processed files are saved in the 'processed_data' folder.")

# %% [markdown]
# ### The next step is to aggregate all the results into a single file

# %%
# Get the preprocessed files
file_paths = [
    f"processed_data/{fp.replace('results/', '').replace('.txt', '_processed.txt')}"
    for fp in file_paths
]
print(file_paths)
# Out:
# ['processed_data/CoT_Zero_shot_results_2024-05-16_14-16-01_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_14-53-06_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_15-29-13_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_15-57-48_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_16-28-12_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_17-01-39_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_17-34-21_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_18-22-13_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_19-38-30_processed.txt', 'processed_data/CoT_Zero_shot_results_2024-05-16_20-06-44_processed.txt']

# %%
def combine_results(file_paths):
    """
    Combine results from multiple files
    For each text -> topics from each file

    Args:
        file_paths (list): the list of file paths that has been preprocessed
    Returns:
        combined_results (list) : list combined results

    """
    combined_results = defaultdict(list)

    for file_path in file_paths:
        with open(file_path, 'r') as file:
            content = file.read().strip().split("\n\n")
            for entry in content:
                if 'Topics' in entry:
                    try:
                        text_part, label_part = entry.split("{'Topics': ")
                        text = text_part.replace("Text: ", "").strip()
                        topics = "{'Topics': " + label_part.strip()
                        combined_results[text].append(topics)
                    except ValueError:
                        print(f"Skipping entry due to parsing error: {entry}")

    return combined_results

def aggregate_results(combined_results):
    """
    Aggregate the topics results from multiple files using majority vote

    Args:
        combined_results (list): the list of combined results from preprocessed file (for each text -> topics from each file)
    Returns:
        aggregated_results (list) : list of aggregated results using majority vote

    """
    aggregated_results = {}

    for text, topics in combined_results.items():
        all_topics = [topic.strip() for topic_list in topics for topic in topic_list.replace("{'Topics': ", "").replace("}", "").split(',')]
        topic_counts = Counter(all_topics)
        majority_topics = [topic for topic, count in topic_counts.items() if count >= (len(file_paths) / 2) ]
        aggregated_results[text] = majority_topics

    return aggregated_results

def save_combined_results(combined_results, output_path):
    """
    Save in a new file the combined results from multiple files
    For each text -> topics from each file

    Args:
        combined_results (list): the list of combined results from preprocessed file (for each text -> topics from each file)
        output_path (str): the output path of the new file

    """
    with open(output_path, 'w') as file:
        for text, topics_list in combined_results.items():
            file.write(f"Text: {text}\n")
            for topics in topics_list:
                file.write(f"{topics}\n")
            file.write("\n")

def save_aggregated_results(aggregated_results, output_path):
    """
    Save the aggregated results

    Args:
        aggregated_results (list) : list of aggregated results using majority vote
        output_path (str): the output path of the new file
    """
    with open(output_path, 'w') as file:
        for text, topics in aggregated_results.items():
            file.write(f"Text: {text}\n")
            file.write(f"Assigned Topics: {', '.join(topics)}\n\n")
# Out:
# ('aggregated_results/Combined_Results_CoT_Zero_shot.txt',
#  'aggregated_results/Aggregated_Results_CoT_Zero_shot.txt')

# %%
# Define the output paths for the combined and aggregated results text files

output_combined_text_path = 'aggregated_results/Combined_Results_' + method +'.txt'
output_aggregated_text_path = 'aggregated_results/Aggregated_Results_' + method +'.txt'

# Combine the results from the text files into the desired format
combined_results = combine_results(file_paths)

# Save the combined results to a text file
save_combined_results(combined_results, output_combined_text_path)

# Aggregate the results using majority vote
aggregated_results = aggregate_results(combined_results)

# Save the aggregated results to a text file
save_aggregated_results(aggregated_results, output_aggregated_text_path)

(output_combined_text_path, output_aggregated_text_path)

# %% [markdown]
# ### Final step for preprocessing results: saving the aggregated results in a csv file

# %%
# Input an empty dataset (without the labels of the data)
empty_df = pd.read_csv('Empty_data_set.csv', delimiter=';')

# Define the mapping of labels to column names
label_to_column = {
    '1': 'Municipality and residents engagement in the energy sector',
    '2': 'Energy storage and supplying energy in The Netherlands',
    '3': 'Wind and solar energy',
    '4': 'Market Determination Dynamics',
    '5': 'Landscapes and windmills tourism',
    '6': 'Hydrogen energy pipeline networks'
}

# Initialize a dictionary to store text to index mapping
text_to_index = {}

# Map text to their row index in the empty CSV file
for idx, row in empty_df.iterrows():
    text = row['english'].strip()
    text_to_index[text] = idx

# Initialize all columns to '0'
for column in label_to_column.values():
    empty_df[column] = '0'

# Fill the columns based on the aggregated labels from the Aggregated_Results.txt file
output_aggregated_text_path = "aggregated_results/Aggregated_Results_"+ method + ".txt"
with open(output_aggregated_text_path, 'r') as file:
    content = file.read().strip().split("\n\n")
    for entry in content:
        lines = entry.split("\n")
        if len(lines) < 2:
            continue
        text = lines[0].replace("Text: ", "").strip()
        topics_line = lines[1].replace("Assigned Topics: ", "").strip()
        topics = topics_line.split(", ") if topics_line else []
        if text in text_to_index:
            idx = text_to_index[text]
            for label, column_name in label_to_column.items():
                if label in topics:
                    empty_df.at[idx, column_name] = '1'

# Save the filled CSV file
filled_csv_path_final = 'llm_annotated_data/Results_' + method +'.csv'
empty_df.to_csv(filled_csv_path_final, index=False, sep=';')

filled_csv_path_final
# Out:
# 'llm_annotated_data/Results_CoT_Zero_shot.csv'
