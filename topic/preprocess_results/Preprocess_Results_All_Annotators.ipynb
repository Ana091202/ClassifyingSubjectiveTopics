# %% [markdown]
# # Preprocess the results of LLM prompting methods for all annotators

# %% [markdown]
# ### Import libraries and install the embedding model

# %%
# !pip install sentence-transformers

# %%
import os
import re
import json
import numpy as np
import pandas as pd
from sentence_transformers import SentenceTransformer, util
from collections import defaultdict, Counter

# %% [markdown]
# ### File paths to preprocess

# %%
# List of files to preprocess
file_paths = [
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-20-45.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-34-02.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-49-27.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-04-30.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-21-15.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-36-55.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-53-17.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-06-36.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-21-36.txt',
    'results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-36-29.txt'
]

# The training method
method = "RaR-Few-shot-CoT-Emotion-Prompt"

# Number of annotators
number_of_annotators = 5

# %%
def save_results_per_annotator(file_path, output_dir):
    """
    Save results per annotator

    Args:
        file_path (str): the name of the file used to save the individual annotators results
        output_dir (str): the output directory where to save the individual results
    """
    with open(file_path, 'r', encoding='ISO-8859-1') as file:
        for line in file:
            try:
                entry = json.loads(line)  # Try to parse each line as a JSON object
                text = entry["text"]
                content = entry["content"]
                annotator_pattern = re.compile(r"Annotator (\d+) - \{(.*?)\}", re.DOTALL)
                annotators = annotator_pattern.findall(content)
                base_name = os.path.splitext(os.path.basename(file_path))[0]

                for annotator_id, topics_raw in annotators:
                    topics_formatted = "{" + topics_raw + "}"
                    output_path = os.path.join(output_dir, f'{base_name}_Annotator_{annotator_id}.txt')
                    result = "Text: "+ text + '\n' + topics_formatted + '\n\n'
                    with open(output_path, 'a', encoding='utf-8') as output_file:
                        print(result)
                        output_file.write(result)
            except json.JSONDecodeError as e:
                print(f"Failed to decode JSON from line in file {file_path}: {str(e)}")
# Out:
# Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# {'Topics': Municipality and residents engagement in the energy sector, Market Determination Dynamics}
#
#
# Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# {'Topics': Energy storage and supplying energy in The Netherlands, Wind and solar energy}
#
#
# Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# {'Topics': Municipality and residents engagement in the energy sector}
#
#
# Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# {'Topics': Market Determination Dynamics}
#
#
# Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# {'Topics': Municipality and residents engagement in the energy sector}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Municipality and residents engagement in the energy sector, Market Determination Dynamics, Energy storage and supplying energy in The Netherlands}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Wind and solar energy}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Energy storage and supplying energy in The Netherlands}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Landscapes and windmills tourism, Hydrogen energy pipeline networks}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': Topic1, Topic2, Topic3}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': Topic1, Topic2, Topic4}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': Topic1, Topic2, Topic5}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': Topic1, Topic2, Topic6}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': Topic2, Topic3, Topic4}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# {'Topics': 'Energy storage', 'Supplying energy in The Netherlands'}
#
#
# Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# {'Topics': 'Wind and solar energy', 'Landscapes and windmills tourism'}
#
#
# Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# {'Topics': 'Market Determination Dynamics', 'Hydrogen energy pipeline networks'}
#
#
# Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# {'Topics': 'Hydrogen energy pipeline networks', 'Wind and solar energy'}
#
#
# Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Energy storage and supplying energy in The Netherlands, Municipality and residents engagement in the energy sector}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Municipality and residents engagement in the energy sector}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Wind and solar energy}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': None}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Energy storage and supplying energy in The Netherlands}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Wind and solar energy', 'Market Determination Dynamics'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Market Determination Dynamics', 'Municipality and residents engagement in the energy sector'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Wind and solar energy'}
#
#
# Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# {'Topics': Topic1, Topic2, Topic3}
#
#
# Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# {'Topics': Topic2, Topic3, Topic4}
#
#
# Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# {'Topics': Topic3, Topic4, Topic5}
#
#
# Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# {'Topics': Topic4, Topic5, Topic6}
#
#
# Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# {'Topics': Topic5, Topic6, Topic7}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage', 'Supplying energy'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Energy storage', 'Supplying energy', 'Wind and solar energy'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Landscapes', 'Tourism', 'Windmills'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Hydrogen energy', 'Pipeline networks', 'Infrastructure and logistics'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Wind and solar energy', 'Community involvement in energy production'}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': ['Politics', 'Economy'], Annotator 2 - {'Topics': ['Sports', 'Entertainment'], Annotator 3 - {'Topics': ['Technology', 'Science'], Annotator 4 - {'Topics': ['Lifestyle', 'Culture'], Annotator 5 - {'Topics': ['Health', 'Education']}
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Market Determination Dynamics }
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Energy storage and supplying energy in The Netherlands, Market Determination Dynamics }
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Market Determination Dynamics }
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands }
#
#
# Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands }
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'Market Determination Dynamics'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'Wind and solar energy'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'Market Determination Dynamics'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'Wind and solar energy'}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': Topic1, Topic2}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': Topic2, Topic3}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': Topic1, Topic3}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': Topic2, Topic4}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': Topic1, Topic4}
#
#
# Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'}
#
#
# Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# {'Topics': 'Market Determination Dynamics', 'Wind and solar energy'}
#
#
# Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# {'Topics': 'Wind and solar energy'}
#
#
# Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Hydrogen energy pipeline networks'}
#
#
# Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# {'Topics': 'Hydrogen energy pipeline networks'}
#
#
# Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': Energy sector engagement, Energy storage and supply in The Netherlands, Wind and solar energy}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': Market determination dynamics, Landscapes and windmills tourism, Hydrogen energy pipeline networks}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': Residents' engagement in the energy sector, Energy storage and supply in The Netherlands, Wind and solar energy}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': Municipality and residents' engagement in the energy sector, Energy storage and supply in The Netherlands, Wind and solar energy}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': Sustainable initiatives, Market economy opportunity, Local innovation and development}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Municipality and residents engagement in the energy sector, Wind and solar energy, Market Determination Dynamics}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Landscapes and windmills tourism, Hydrogen energy pipeline networks}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': None}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': None}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': None}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': 'Market Determination Dynamics', 'Wind and solar energy'}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': 'Wind and solar energy', 'Hydrogen energy pipeline networks'}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': 'Landscapes and windmills tourism', 'Wind and solar energy'}
#
#
# Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# {'Topics': 'Hydrogen energy pipeline networks', 'Municipality and residents engagement in the energy sector'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'A', 'B', 'C'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'D', 'E', 'F'}
#
#
# Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# {'Topics': 'G', 'H', 'I'}
#
#
# Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# {'Topics': Market Determination Dynamics, Municipality and Residents Engagement in the Energy Sector}
#
#
# Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# {'Topics': Market Determination Dynamics, Wind and Solar Energy}
#
#
# Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# {'Topics': Landscapes and Windmills Tourism, Hydrogen Energy Pipeline Networks}
#
#
# Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# {'Topics': Landscapes and Windmills Tourism, Wind and Solar Energy}
#
#
# Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# {'Topics': Hydrogen Energy Pipeline Networks, Market Determination Dynamics}
#
#
# Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# {'Topics': Energy storage and supplying energy in The Netherlands}
#
#
# Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# {'Topics': Wind and solar energy}
#
#
# Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# {'Topics': Market Determination Dynamics}
#
#
# Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# {'Topics': Landscapes and windmills tourism}
#
#
# Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# {'Topics': Hydrogen energy pipeline networks}
#
#
# Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# {'Topics': ['Topic1', 'Topic2', 'Topic3']}
#
#
# Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# {'Topics': ['Topic1', 'Topic2', 'Topic4']}
#
#
# Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# {'Topics': ['Topic1', 'Topic2', 'Topic5']}
#
#
# Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# {'Topics': ['Topic1', 'Topic2', 'Topic6']}
#
#
# Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# {'Topics': ['Topic1', 'Topic2', 'Topic7']}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': 'food', 'travel', 'culture'}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': 'food', 'history', 'politics'}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': 'food', 'science', 'technology'}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': 'food', 'entertainment', 'sports'}
#
#
# Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# {'Topics': 'food', 'education', 'health'}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, ...}
#
#
# Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# {'Topics': Energy sector involvement, Resident engagement, Market Determination Dynamics}
#
#
# Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# {'Topics': Landscapes, Windmills tourism, Market Dynamics}
#
#
# Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# {'Topics': Renewable energy sources, Solar power, Wind power}
#
#
# Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# {'Topics': Hydrogen energy, Pipeline networks}
#
#
# Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# {'Topics': None}
#
#
# Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy transition and sustainability'}
#
#
# Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# {'Topics': 'Energy transition and sustainability', 'Municipality and residents engagement in the energy sector'}
#
#
# Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# {'Topics': 'Energy policy and regulations', 'Sustainable development and environment'}
#
#
# Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# {'Topics': 'Sustainable development and environment', 'Energy policy and regulations'}
#
#
# Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# {'Topics': 'Energy efficiency and conservation', 'Renewable energy sources'}
#
#
# Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# {'Topics': 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# {'Topics': 'Wind and solar energy'}
#
#
# Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# {'Topics': 'Municipality and residents engagement in the energy sector'}
#
#
# Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# {'Topics': 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': [Topic1, Topic2, ...], 'Comments': Comments1}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': [Topic1, Topic2, ...], 'Comments': Comments2}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': [Topic1, Topic2, ...], 'Comments': Comments3}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': [Topic1, Topic2, ...], 'Comments': Comments4}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': [Topic1, Topic2, ...], 'Comments': Comments5}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Market Determination Dynamics', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Landscapes and windmills tourism', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'}
#
#
# Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# {'Topics': 'Wind and solar energy', 'Municipality and residents engagement in the energy sector'}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Municipality and Residents Engagement in the Energy Sector, Market Determination Dynamics}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Market Determination Dynamics}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Wind and Solar Energy}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Municipality and Residents Engagement in the Energy Sector}
#
#
# Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# {'Topics': Wind and Solar Energy}
#
#
# Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# {'Topics': 'Competition from each other', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# {'Topics': 'Competition from each other', 'Market Determination Dynamics'}
#
#
# ...
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Energy storage, Supplying energy in The Netherlands}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Landscapes, Windmills tourism}
#
#
# Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector'}
#
#
# Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# {'Topics': 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector'}
#
#
# Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector'}
#
#
# Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# {'Topics': None}
#
#
# Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# {'Topics': Municipality's role in the energy transition, Citizen engagement in the energy sector}
#
#
# Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# {'Topics': Energy storage and supplying energy in The Netherlands, Wind and solar energy}
#
#
# Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# {'Topics': Market Determination Dynamics, Landscapes and windmills tourism}
#
#
# Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# {'Topics': Citizen engagement in the energy sector, Wind and solar energy}
#
#
# Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# {'Topics': Municipality's role in the energy transition, Energy storage and supplying energy in The Netherlands}
#
#
# Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃºdwest-FryslÃ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# {'Topics': 'Municipality and resident engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃºdwest-FryslÃ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# {'Topics': 'Energy storage and supply in The Netherlands', 'Wind and solar energy'}
#
#
# Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃºdwest-FryslÃ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# {'Topics': 'Wind and solar energy', 'Market Determination Dynamics'}
#
#
# Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃºdwest-FryslÃ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# {'Topics': 'Market Determination Dynamics', 'Landscapes and windmills tourism'}
#
#
# Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃºdwest-FryslÃ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# {'Topics': 'Landscapes and windmills tourism', 'Municipality and resident engagement in the energy sector'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': 'Energy storage and supplying energy in The Netherlands', 'Renewable energy sources'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': 'Energy storage and supplying energy in The Netherlands', 'Renewable energy sources'}
#
#
# Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices'}
#
#
# Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy}
#
#
# Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# {'Topics': Market Determination Dynamics, Landscapes and windmills tourism}
#
#
# Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# {'Topics': Hydrogen energy pipeline networks}
#
#
# Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# {'Topics': None of the topics are relevant}
#
#
# Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# {'Topics': Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Wind and solar energy', 'Municipality and residents engagement in the energy sector'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'}
#
#
# Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# {'Topics': municipality and resident engagement in energy sector, sustainability within framework of design}
#
#
# Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# {'Topics': control and approval by municipality}
#
#
# Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# {'Topics': sustainability within framework of design}
#
#
# Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# {'Topics': energy sector strategy}
#
#
# Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# {'Topics': energy storage or supply in Netherlands}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': 'Wind and solar energy', 'Market Determination Dynamics'}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': 'Landscapes and windmills tourism', 'Hydrogen energy pipeline networks'}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': 'Hydrogen energy pipeline networks'}
#
#
# Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# {'Topics': 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'}
#
#
# Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# {'Topics': 'Wind and solar energy'}
#
#
# Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# {'Topics': 'Market Determination Dynamics'}
#
#
# Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# {'Topics': 'Landscapes and windmills tourism'}
#
#
# Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# {'Topics': 'Hydrogen energy pipeline networks'}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, Topic3}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, Topic4}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, Topic3}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, Topic4}
#
#
# Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# {'Topics': Topic1, Topic2, Topic4}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Energy storage, Supplying energy in The Netherlands}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Municipality and residents engagement, Energy sector}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Wind and solar energy}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Market Determination Dynamics}
#
#
# Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# {'Topics': Landscapes and windmills tourism}
#
#
# Processing completed. Processed files are saved in the 'individual_annotators_results' folder.

# %%
output_dir = "individual_annotators_results"
for file_path in file_paths:
    save_results_per_annotator(file_path, output_dir)

print("Processing completed. Processed files are saved in the 'individual_annotators_results' folder.")

# %%
# Mapping dictionary for topics
topic_mapping = {
    "municipality and residents engagement in the energy sector": 1,
    "residents engagement": 1,
    "municipality engagement": 1,
    "residents engagement in the energy sector": 1,
    "municipality engagement in the energy sector": 1,
    "energy storage and supplying energy in the netherlands": 2,
    "energy storage and supply in the netherlands": 2,
    "energy storage in the netherlands": 2,
    "supplying energy in the netherlands": 2,
    "energy storage": 2,
    "wind and solar energy": 3,
    "solar energy": 3,
    "wind energy": 3,
    "market determination dynamics": 4,
    "market dynamics": 4,
    "market determination": 4,
    "landscapes and windmills tourism": 5,
    "landscapes and windmills": 5,
    "hydrogen energy pipeline networks": 6,
    "hydrogen energy pipeline": 6
}

# Load the Sentence Transformer model
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')

# Pre-compute embeddings for topic mapping keys
topic_embeddings = {topic: model.encode(topic, convert_to_tensor=True) for topic in topic_mapping.keys()}

def is_valid_topic(topic):
    """
    Check if a topic string is valid (not empty) when removing special characters

    Args:
        topic (str): the topic string
    Returns:
        bool : True if topic is valid, False otherwise

    """
    # Remove special characters and check if the resulting string is empty
    return re.sub(r'[^A-Za-z0-9]+', '', topic).strip() != ''

def process_topics(topics):
    """
    Map the topic list to the original list of topics
    The mapping is done using Sentence-Transformers embedding model (if the topic is not in 'topic_mapping')

    Args:
        topics (list): the list of topics to be preprocessed
    Returns:
        topic_numbers (list) : list of indices indicating the mapping of the topics to the original list

    """
    # Extract numbers and topic strings from the topics
    topic_numbers = set()
    threshold = 0.70  # Cosine similarity threshold for similarity

    if isinstance(topics, int):
        topic_numbers.add(topics)
    elif isinstance(topics, list):
        for topic in topics:
            if isinstance(topic, int):
                topic_numbers.add(topic)
            elif topic.isdigit():
                topic_numbers.add(int(topic))
            else:
                topic_lower = topic.lower().strip()  # Convert to lowercase
                if is_valid_topic(topic_lower):
                    topic_embedding = model.encode(topic_lower, convert_to_tensor=True)
                    # Perform cosine similarity matching
                    similarities = {key: util.pytorch_cos_sim(topic_embedding, emb).item() for key, emb in topic_embeddings.items()}
                    matched_topic, score = max(similarities.items(), key=lambda x: x[1])
                    if score >= threshold:
                        topic_numbers.add(topic_mapping[matched_topic])
                    else:
                        print(f"Low match score for topic '{topic}': {score}")
                else:
                    print(f"Invalid topic '{topic}'")
    elif isinstance(topics, str):
        topic_lower = topics.lower().strip()  # Convert to lowercase
        if is_valid_topic(topic_lower):
            topic_embedding = model.encode(topic_lower, convert_to_tensor=True)
            # Perform cosine similarity matching
            similarities = {key: util.pytorch_cos_sim(topic_embedding, emb).item() for key, emb in topic_embeddings.items()}
            matched_topic, score = max(similarities.items(), key=lambda x: x[1])
            if score >= threshold:
                topic_numbers.add(topic_mapping[matched_topic])
            else:
                print(f"Low match score for topic '{topics}': {score}")
        else:
            print(f"Invalid topic '{topics}'")

    # Remove None values and sort the topics
    topic_numbers = sorted([t for t in topic_numbers if t is not None])
    return topic_numbers

def preprocess_file(file_path, processed_data_dir):
    """
    Preprocess file with results to map the topics to the original topics list
    Writes the preprocessed file in a new file with the name 'file_path_processed'  in the folder 'results'
    Args:
        file_path (str): the file path to preprocess
        processed_data_dir (str): the output to save the file

    """
    processed_lines = []

    print(f"Processing file: {file_path}")

    with open(file_path, 'r', encoding='latin1') as file:
        lines = file.readlines()
        i = 0
        while i < len(lines):
            line = lines[i].strip()
            if line.lower().startswith("text:"):
                text_line = line
                print(f"Found text: {text_line}")
                i += 1
                while i < len(lines) and not lines[i].strip().lower().startswith("text:"):
                    line = lines[i].strip()
                    if re.search(r"\{'Topics':(.+?)\}", line):
                        match = re.search(r"\{'Topics':(.+?)\}", line)
                        topics_str = match.group(1).strip()
                    elif re.search(r"\['Topics':(.+?)\]", line):
                        match = re.search(r"\['Topics':(.+?)\]", line)
                        topics_str = match.group(1).strip()
                    else:
                        i += 1
                        continue

                    print(f"Found topics string: {topics_str}")

                    try:
                        topics = json.loads(topics_str.replace("'", "\""))
                        if isinstance(topics, str):
                            topics = [topics]
                        elif isinstance(topics, dict):
                            topics = [topics]
                    except json.JSONDecodeError:
                        topics = re.findall(r"'(.*?)'", topics_str) + re.findall(r"(\d+)", topics_str)

                    if not topics:
                        topics = topics_str.split(', ')

                    print(f"Extracted topics: {topics}")
                    processed_topics = process_topics(topics)
                    print(f"Processed topics: {processed_topics}")
                    processed_lines.append(f"{text_line}\n")
                    processed_lines.append(f"{{'Topics': {', '.join(map(str, processed_topics))}}}\n")
                    processed_lines.append("\n")
                    break
            elif line.strip().startswith("['Topics") or line.strip().startswith("Topics") or line.strip().startswith("'Topics"):
                topics_str = line.split(":", 1)[1].strip().strip('[]')
                print(f"Found topics string: {topics_str}")

                try:
                    topics = json.loads(topics_str.replace("'", "\""))
                    if isinstance(topics, str):
                        topics = [topics]
                    elif isinstance(topics, dict):
                        topics = [topics]
                except json.JSONDecodeError:
                    topics = re.findall(r"'(.*?)'", topics_str) + re.findall(r"(\d+)", topics_str)

                if not topics:
                    topics = topics_str.split(', ')

                print(f"Extracted topics: {topics}")
                processed_topics = process_topics(topics)
                print(f"Processed topics: {processed_topics}")
                processed_lines.append(f"{{'Topics': {', '.join(map(str, processed_topics))}}}\n")
                processed_lines.append("\n")
            i += 1
    # Save the processed file to the processed_data directory
    output_path = os.path.join(processed_data_dir, os.path.basename(file_path).replace(".txt", "_processed.txt"))
    with open(output_path, 'w', encoding='latin1') as output_file:
        output_file.writelines(processed_lines)
    print(f"Finished processing file: {file_path}")
    print(f"Processed file saved to: {output_path}\n")
# Out:
# C:\Users\marcu\AppData\Local\Programs\Python\Python312\Lib\site-packages\huggingface_hub\file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
# Ensure the processed_data directory exists
processed_data_dir = 'processed_data'
os.makedirs(processed_data_dir, exist_ok=True)
output_dir = "individual_annotators_results"
for annotator_id in range(5):
    file_paths_per_annotator = [
        f"individual_annotators_results/{fp.replace('results/', '').replace('.txt', '_Annotator_' + str(annotator_id + 1) +  '.txt')}"
        for fp in file_paths
    ]
    for file in file_paths_per_annotator:
        preprocess_file(file, processed_data_dir)
# Out:
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-20-45_Annotator_1.txt
# Found text: Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# Found topics string: Municipality and residents engagement in the energy sector, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Energy storage and supplying energy in The Netherlands, Municipality and residents engagement in the energy sector
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 2]
# Found text: Text: The market is not a reliable partner. The yield is important and nature and the environment are secondary, if damage occurs there then so be it. Until now, the working method was as just described. Perhaps the municipality can play a coercive role in this and only cooperate with market parties if the damage is 0 or repaired as much as possible at the expense of the market party.
# Found topics string: Municipality and residents engagement in the energy sector, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Energy storage and supplying energy in The Netherlands, Municipality and residents engagement in the energy sector
# Extracted topics: ['Energy storage and supplying energy in The Netherlands', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 2]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-20-45_Annotator_1.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-20-45_Annotator_1_processed.txt
#
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-34-02_Annotator_1.txt
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage', 'Supplying energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage', 'Supplying energy']
# Low match score for topic 'Supplying energy': 0.682388424873352
# Processed topics: [1, 2]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: ['Politics', 'Economy'], Annotator 2 - {'Topics': ['Sports', 'Entertainment'], Annotator 3 - {'Topics': ['Technology', 'Science'], Annotator 4 - {'Topics': ['Lifestyle', 'Culture'], Annotator 5 - {'Topics': ['Health', 'Education']
# Extracted topics: ['Politics', 'Economy', 'Topics', 'Sports', 'Entertainment', 'Topics', 'Technology', 'Science', 'Topics', 'Lifestyle', 'Culture', 'Topics', 'Health', 'Education', '2', '3', '4', '5']
# Low match score for topic 'Politics': 0.3191646933555603
# Low match score for topic 'Economy': 0.5128847360610962
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Sports': 0.2103288471698761
# Low match score for topic 'Entertainment': 0.22271665930747986
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Technology': 0.28569087386131287
# Low match score for topic 'Science': 0.2688605785369873
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Lifestyle': 0.3745667338371277
# Low match score for topic 'Culture': 0.3661060333251953
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Health': 0.12017446011304855
# Low match score for topic 'Education': 0.2469395399093628
# Processed topics: [2, 3, 4, 5]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics']
# Processed topics: [1, 2, 4]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: Topic1, Topic2
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: Energy sector engagement, Energy storage and supply in The Netherlands, Wind and solar energy
# Extracted topics: ['Energy sector engagement', 'Energy storage and supply in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Municipality and residents engagement in the energy sector, Wind and solar energy, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [1, 3, 4]
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: The best way to guarantee that everyone is supplied with electricity green and reliably is to control everything centrally.
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage', 'Supplying energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage', 'Supplying energy']
# Low match score for topic 'Supplying energy': 0.682388424873352
# Processed topics: [1, 2]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: ['Politics', 'Economy'], Annotator 2 - {'Topics': ['Sports', 'Entertainment'], Annotator 3 - {'Topics': ['Technology', 'Science'], Annotator 4 - {'Topics': ['Lifestyle', 'Culture'], Annotator 5 - {'Topics': ['Health', 'Education']
# Extracted topics: ['Politics', 'Economy', 'Topics', 'Sports', 'Entertainment', 'Topics', 'Technology', 'Science', 'Topics', 'Lifestyle', 'Culture', 'Topics', 'Health', 'Education', '2', '3', '4', '5']
# Low match score for topic 'Politics': 0.3191646933555603
# Low match score for topic 'Economy': 0.5128847360610962
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Sports': 0.2103288471698761
# Low match score for topic 'Entertainment': 0.22271665930747986
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Technology': 0.28569087386131287
# Low match score for topic 'Science': 0.2688605785369873
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Lifestyle': 0.3745667338371277
# Low match score for topic 'Culture': 0.3661060333251953
# Low match score for topic 'Topics': 0.26770883798599243
# Low match score for topic 'Health': 0.12017446011304855
# Low match score for topic 'Education': 0.2469395399093628
# Processed topics: [2, 3, 4, 5]
# Found text: Text: Not a good idea. Soon tens of thousands of people will all invent the same gunpowder. ineffective.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Market Determination Dynamics']
# Processed topics: [1, 2, 4]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: Topic1, Topic2
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: Creating something beautiful in a shared community, where everyone contributes to everyone's ability. And it gives a drive because there will also be recouped. My preference is mainly for windmills, and solar panels on existing buildings and certainly not for panels on (agricultural) land.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: Energy sector engagement, Energy storage and supply in The Netherlands, Wind and solar energy
# Extracted topics: ['Energy sector engagement', 'Energy storage and supply in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Municipality and residents engagement in the energy sector, Wind and solar energy, Market Determination Dynamics
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy', 'Market Determination Dynamics']
# Processed topics: [1, 3, 4]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-34-02_Annotator_1.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-34-02_Annotator_1_processed.txt
#
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-49-27_Annotator_1.txt
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'A', 'B', 'C'
# Extracted topics: ['A', 'B', 'C']
# Low match score for topic 'A': 0.2712523341178894
# Low match score for topic 'B': 0.24309316277503967
# Low match score for topic 'C': 0.206072598695755
# Processed topics: []
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: Market Determination Dynamics, Municipality and Residents Engagement in the Energy Sector
# Extracted topics: ['Market Determination Dynamics', 'Municipality and Residents Engagement in the Energy Sector']
# Processed topics: [1, 4]
# Found text: Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# Found topics string: Energy storage and supplying energy in The Netherlands
# Extracted topics: ['Energy storage and supplying energy in The Netherlands']
# Processed topics: [2]
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: ['Topic1', 'Topic2', 'Topic3']
# Extracted topics: ['Topic1', 'Topic2', 'Topic3']
# Low match score for topic 'Topic1': 0.2161533236503601
# Low match score for topic 'Topic2': 0.23669429123401642
# Low match score for topic 'Topic3': 0.2224419116973877
# Processed topics: []
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: 'food', 'travel', 'culture'
# Extracted topics: ['food', 'travel', 'culture']
# Low match score for topic 'food': 0.2020721584558487
# Low match score for topic 'travel': 0.40092480182647705
# Low match score for topic 'culture': 0.3661060333251953
# Processed topics: []
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Found text: Text: The municipality must support energy generation by local energy cooperatives. The municipality should not put on too big pants when it comes to large-scale energy storage. At most, only for your own municipality. The idea of becoming the energy supplier of the Netherlands is also megalomaniacal. That's never going to work in SWF. The market only wants to extract as much money as possible from people.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'A', 'B', 'C'
# Extracted topics: ['A', 'B', 'C']
# Low match score for topic 'A': 0.2712523341178894
# Low match score for topic 'B': 0.24309316277503967
# Low match score for topic 'C': 0.206072598695755
# Processed topics: []
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: Market Determination Dynamics, Municipality and Residents Engagement in the Energy Sector
# Extracted topics: ['Market Determination Dynamics', 'Municipality and Residents Engagement in the Energy Sector']
# Processed topics: [1, 4]
# Found text: Text: Some storage is good, but not for all or half of the Netherlands Then we will soon get landscape pollution
# Found topics string: Energy storage and supplying energy in The Netherlands
# Extracted topics: ['Energy storage and supplying energy in The Netherlands']
# Processed topics: [2]
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: ['Topic1', 'Topic2', 'Topic3']
# Extracted topics: ['Topic1', 'Topic2', 'Topic3']
# Low match score for topic 'Topic1': 0.2161533236503601
# Low match score for topic 'Topic2': 0.23669429123401642
# Low match score for topic 'Topic3': 0.2224419116973877
# Processed topics: []
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: 'food', 'travel', 'culture'
# Extracted topics: ['food', 'travel', 'culture']
# Low match score for topic 'food': 0.2020721584558487
# Low match score for topic 'travel': 0.40092480182647705
# Low match score for topic 'culture': 0.3661060333251953
# Processed topics: []
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: Topic1, Topic2, ...
# Extracted topics: ['1', '2']
# Processed topics: [1, 2]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-49-27_Annotator_1.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_20-49-27_Annotator_1_processed.txt
#
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-04-30_Annotator_1.txt
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: Energy sector involvement, Resident engagement, Market Determination Dynamics
# Extracted topics: ['Energy sector involvement', 'Resident engagement', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy transition and sustainability'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy transition and sustainability']
# Low match score for topic 'Energy transition and sustainability': 0.6161330938339233
# Processed topics: [1]
# Found text: Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: [Topic1, Topic2, ...], 'Comments': Comments1
# Extracted topics: ['Comments', '1', '2', '1']
# Low match score for topic 'Comments': 0.24725353717803955
# Processed topics: [1, 2]
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: Municipality and Residents Engagement in the Energy Sector, Market Determination Dynamics
# Extracted topics: ['Municipality and Residents Engagement in the Energy Sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# Found topics string: 'Competition from each other', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Competition from each other', 'Energy storage and supplying energy in The Netherlands']
# Low match score for topic 'Competition from each other': 0.2866784930229187
# Processed topics: [2]
# Found text: Text: People want to be involved in these kinds of decisions. We want to choose how we make it more sustainable.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: municipality and residents engagement in the energy sector, energy storage and supplying energy in The Netherlands, wind and solar energy, market determination dynamics, landscapes and windmills tourism
# Extracted topics: ['municipality and residents engagement in the energy sector', 'energy storage and supplying energy in The Netherlands', 'wind and solar energy', 'market determination dynamics', 'landscapes and windmills tourism']
# Processed topics: [1, 2, 3, 4, 5]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: Municipality and residents engagement in the energy sector, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy']
# Processed topics: [1, 3]
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: Energy sector involvement, Resident engagement, Market Determination Dynamics
# Extracted topics: ['Energy sector involvement', 'Resident engagement', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: We do not want to become a wind turbine or solar park, or biomass digester for the whole of the Netherlands.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy transition and sustainability'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy transition and sustainability']
# Low match score for topic 'Energy transition and sustainability': 0.6161330938339233
# Processed topics: [1]
# Found text: Text: This statement makes it as if Friesland has to do it alone, while it is precisely nationally that sustainable use must be made. It is precisely cooperation with all provinces that is good because the statement can then become: "Become an energy supplier to EU surrounding countries."
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: [Topic1, Topic2, ...], 'Comments': Comments1
# Extracted topics: ['Comments', '1', '2', '1']
# Low match score for topic 'Comments': 0.24725353717803955
# Processed topics: [1, 2]
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Not a good plan! Generating far too much energy in our municipality to provide parts of the country with energy. See point 5!
# Found topics string: Municipality and Residents Engagement in the Energy Sector, Market Determination Dynamics
# Extracted topics: ['Municipality and Residents Engagement in the Energy Sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: Competition from each other is never bad as long as one can suffer from each other. There are too many options, the consumer must be able to choose.
# Found topics string: 'Competition from each other', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Competition from each other', 'Energy storage and supplying energy in The Netherlands']
# Low match score for topic 'Competition from each other': 0.2866784930229187
# Processed topics: [2]
# Found text: Text: People want to be involved in these kinds of decisions. We want to choose how we make it more sustainable.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Control is needed to prevent energy from being generated everywhere and with initiatives that are too small. Moreover, it is good if the government has a finger in the pie and (large) companies do not determine what happens. You certainly need the companies, but the government can keep a grip on this with steering measures (including subsidies, location policy, etc.).
# Found topics string: Topic1, Topic2, Topic3
# Extracted topics: ['1', '2', '3']
# Processed topics: [1, 2, 3]
# Found text: Text: The generation and consumption is never simultaneous as you can store create your independence Also I see employment here Now I want solar panels but hear in our street that the solar inverter regularly switches off 250v. This is now an obstacle to purchasing panels, so network / infrastructure will have to be made suitable
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: As a 3rd choice. The market economy must also be given the opportunity. It is precisely a combination of different initiatives that seems to me to be desirable. The market should not prevail, then big money/power wins. Sustainable (people, profit and planet). The economy/market, preferably local, must remain a possibility, with a chance of innovation/development.
# Found topics string: municipality and residents engagement in the energy sector, energy storage and supplying energy in The Netherlands, wind and solar energy, market determination dynamics, landscapes and windmills tourism
# Extracted topics: ['municipality and residents engagement in the energy sector', 'energy storage and supplying energy in The Netherlands', 'wind and solar energy', 'market determination dynamics', 'landscapes and windmills tourism']
# Processed topics: [1, 2, 3, 4, 5]
# Found text: Text: In this way, all residents pay a lot, while a large part of the municipality itself has just invested a lot in insulation and solar panels. The municipality already has a large deficit, so I do not think it is wise to invest in such projects yourself. Sit down with the business community. For the less fortunate it is a godsend, which is why I have given a few points. Perhaps subsidies could be given on the basis of income?
# Found topics string: Municipality and residents engagement in the energy sector, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy']
# Processed topics: [1, 3]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-04-30_Annotator_1.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-04-30_Annotator_1_processed.txt
#
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_21-21-15_Annotator_1.txt
# Found text: Text: With more storage, more energy can perhaps be stored at peak times that can be used at another time. (i.e. ultimately generate less in total capacity)
# Found topics string: municipality and residents engagement in the energy sector, energy storage and supply
# Extracted topics: ['municipality and residents engagement in the energy sector', 'energy storage and supply']
# Processed topics: [1, 2]
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: wind, solar, hydrogen, market, landscape
# Extracted topics: ['wind', 'solar', 'hydrogen', 'market', 'landscape']
# Low match score for topic 'landscape': 0.5452307462692261
# Processed topics: [3, 4, 6]
# Found text: Text: I don't think you can leave this entirely to the inhabitants. But in my view, private initiatives should be possible.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: Residents can take care of solar panels, heat pumps, etc. POSSIBLY WITH THE HELP OF GOOD FINANCING PROGRAMS.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Wind and solar energy'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Wind and solar energy']
# Processed topics: [1, 3]
# Found text: Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃÂºdwest-FryslÃÂ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# Found topics string: None
# Extracted topics: ['None']
# Low match score for topic 'None': 0.09362505376338959
# Processed topics: []
# Found text: Text: Is an important element because it allows self-use to be further stimulated. In my opinion, essential. Furthermore, biomass and pallet stoves should be removed from the package as soon as possible. Then rather nuclear energy as a transition!
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: direction from the public party (steering on the fair distribution of benefits and burdens) and ensuring the quality of the landscape
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Is think this is easiest solution and probably the cheapest? However, this often causes a disruption of the landscape / environment (large fields with solar panels, for example)
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: With more storage, more energy can perhaps be stored at peak times that can be used at another time. (i.e. ultimately generate less in total capacity)
# Found topics string: municipality and residents engagement in the energy sector, energy storage and supply
# Extracted topics: ['municipality and residents engagement in the energy sector', 'energy storage and supply']
# Processed topics: [1, 2]
# Found text: Text: Both residents and the municipalities cannot fulfil the task of the RES together, so a small part will be filled by market parties, but the region will decide/benefit from such projects.
# Found topics string: wind, solar, hydrogen, market, landscape
# Extracted topics: ['wind', 'solar', 'hydrogen', 'market', 'landscape']
# Low match score for topic 'landscape': 0.5452307462692261
# Processed topics: [3, 4, 6]
# Found text: Text: I don't think you can leave this entirely to the inhabitants. But in my view, private initiatives should be possible.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# ...
# Processed topics: [1]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: Topic1, Topic2, Topic7
# Extracted topics: ['1', '2', '7']
# Processed topics: [1, 2, 7]
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: 'Wind and solar energy', 'Municipality and residents engagement in the energy sector'
# Extracted topics: ['Wind and solar energy', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 3]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: 'Hydrogen energy pipeline networks', 'Landscapes and windmills tourism', 'Recycling batteries over years'
# Extracted topics: ['Hydrogen energy pipeline networks', 'Landscapes and windmills tourism', 'Recycling batteries over years']
# Low match score for topic 'Recycling batteries over years': 0.4278225302696228
# Processed topics: [5, 6]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Landscapes, Windmills tourism
# Extracted topics: ['Landscapes', 'Windmills tourism']
# Low match score for topic 'Landscapes': 0.5887455940246582
# Processed topics: [5]
# Found text: Text: We have the space in the countryside to generate more than we consume. We owe our entire polder country to wind energy. The wind is nice here. Let's do more than our part here. They are opportunities. A new landscape is not necessarily a bad landscape. But let the profits descend locally. People have been given a little more to spend, e.g. for sustainable products, which are now slightly more expensive. Living and building land is far too expensive in Ned. Too much money is being knocked out of people's pockets for housing. Because of these high costs, the willingness to invest in sustainability is lower than in the surrounding countries.
# Found topics string: Municipality and residents engagement in the energy sector
# Extracted topics: ['Municipality and residents engagement in the energy sector']
# Processed topics: [1]
# Found text: Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# Found topics string: None of the topics are applicable
# Extracted topics: ['None of the topics are applicable']
# Low match score for topic 'None of the topics are applicable': 0.14679493010044098
# Processed topics: []
# Found text: Text: Especially financially, this seems to me to be the best choice, and also that in a certain (city) district an equality of the houses there arises and no jumble of possible possibilities.
# Found topics string: 'Municipality and residents engagement in the energy sector'
# Extracted topics: ['Municipality and residents engagement in the energy sector']
# Processed topics: [1]
# Found text: Text: If we are going to get rid of gas, it is important that energy is always available. Prefer to store a lot and deliver little. This allows us to become independent of the major energy suppliers.
# Found topics string: Topic1, Topic2, Topic7
# Extracted topics: ['1', '2', '7']
# Processed topics: [1, 2, 7]
# Found text: Text: This is the best solution for the protection of the landscape. Generating sustainable energy in places (small or large) can cause great annoyance. People will always disagree. In those cases, it may be better for the government to make the decision. It should not be the case that the 2 large cores in SWF are now also saddled with large-scale energy generation. There are plenty of (remote) places in the municipality where this could also be done without affecting the landscape too much.
# Found topics string: 'Wind and solar energy', 'Municipality and residents engagement in the energy sector'
# Extracted topics: ['Wind and solar energy', 'Municipality and residents engagement in the energy sector']
# Processed topics: [1, 3]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: 'Hydrogen energy pipeline networks', 'Landscapes and windmills tourism', 'Recycling batteries over years'
# Extracted topics: ['Hydrogen energy pipeline networks', 'Landscapes and windmills tourism', 'Recycling batteries over years']
# Low match score for topic 'Recycling batteries over years': 0.4278225302696228
# Processed topics: [5, 6]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Landscapes, Windmills tourism
# Extracted topics: ['Landscapes', 'Windmills tourism']
# Low match score for topic 'Landscapes': 0.5887455940246582
# Processed topics: [5]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-21-36_Annotator_5.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-21-36_Annotator_5_processed.txt
#
# Processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-36-29_Annotator_5.txt
# Found text: Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# Found topics string: None
# Extracted topics: ['None']
# Low match score for topic 'None': 0.09362505376338959
# Processed topics: []
# Found text: Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# Found topics string: Municipality's role in the energy transition, Energy storage and supplying energy in The Netherlands
# Extracted topics: ["Municipality's role in the energy transition", 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃÂºdwest-FryslÃÂ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# Found topics string: 'Landscapes and windmills tourism', 'Municipality and resident engagement in the energy sector'
# Extracted topics: ['Landscapes and windmills tourism', 'Municipality and resident engagement in the energy sector']
# Processed topics: [1, 5]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices']
# Low match score for topic 'Energy market dynamics and prices': 0.6008169651031494
# Processed topics: [1]
# Found text: Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: energy storage or supply in Netherlands
# Extracted topics: ['energy storage or supply in Netherlands']
# Processed topics: [2]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# Found topics string: 'Hydrogen energy pipeline networks'
# Extracted topics: ['Hydrogen energy pipeline networks']
# Processed topics: [6]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: Topic1, Topic2, Topic4
# Extracted topics: ['1', '2', '4']
# Processed topics: [1, 2, 4]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Landscapes and windmills tourism
# Extracted topics: ['Landscapes and windmills tourism']
# Processed topics: [5]
# Found text: Text: In many cases, the market will determine what comes. However, this is a task for the municipal administration to keep control of whether plans and products are also sustainable and profitable for the municipality.
# Found topics string: None
# Extracted topics: ['None']
# Low match score for topic 'None': 0.09362505376338959
# Processed topics: []
# Found text: Text: Better the municipality than a higher government like the province or The Hague. Keep it close to the citizen.
# Found topics string: Municipality's role in the energy transition, Energy storage and supplying energy in The Netherlands
# Extracted topics: ["Municipality's role in the energy transition", 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: I don't see anything in this. The landscape is helped to the sodemieter while SÃÂºdwest-FryslÃÂ¢n is a tourist-oriented municipality. This is therefore, in my view, a stupid and self-defeating idea.
# Found topics string: 'Landscapes and windmills tourism', 'Municipality and resident engagement in the energy sector'
# Extracted topics: ['Landscapes and windmills tourism', 'Municipality and resident engagement in the energy sector']
# Processed topics: [1, 5]
# Found text: Text: This would be a very good option because the inhabitants can then make their own choices. However, it can also become a mess. So there is a need for direction and frameworks from the province. The costs also influence the choices and most residents have little insight into this.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy market dynamics and prices']
# Low match score for topic 'Energy market dynamics and prices': 0.6008169651031494
# Processed topics: [1]
# Found text: Text: Given the impact of the measures, right behind the front door, it seems better to put the control in the hands of municipalities and residents. The market can go out.
# Found topics string: Municipality and residents engagement in the energy sector, Energy storage and supplying energy in The Netherlands, Wind and solar energy
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands', 'Wind and solar energy']
# Processed topics: [1, 2, 3]
# Found text: Text: Can keep the balance between peaple - planet - profit. Although it will soon be in their favor. That is why good agreements must be made with the municipality.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Market Determination Dynamics'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Market Determination Dynamics']
# Processed topics: [1, 4]
# Found text: Text: private individuals who can afford it and do things approved by the municipality in the context of sustainability, which also fits within the framework of design (i.e. well controlled by the municipality) is a good thing and can contribute to the joint solution
# Found topics string: energy storage or supply in Netherlands
# Extracted topics: ['energy storage or supply in Netherlands']
# Processed topics: [2]
# Found text: Text: I think this is a very good idea because it yields a lot for the municipality and for the Netherlands. Because the municipality can earn a lot from it and so can the Netherlands.
# Found topics string: 'Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands'
# Extracted topics: ['Municipality and residents engagement in the energy sector', 'Energy storage and supplying energy in The Netherlands']
# Processed topics: [1, 2]
# Found text: Text: Not everyone who wants to can invest in solar panels. Windmills are not an issue, we have enough of them in the municipality and we no longer want windmills that pollute the horizon.
# Found topics string: 'Hydrogen energy pipeline networks'
# Extracted topics: ['Hydrogen energy pipeline networks']
# Processed topics: [6]
# Found text: Text: I don't think there is this possibility yet, these battery packs have to be housed somewhere (building local). This is 1 of the better solution for the future or that in every home that is equipped with panels and backup to have but you also have to look at recycling the batteries over years.
# Found topics string: Topic1, Topic2, Topic4
# Extracted topics: ['1', '2', '4']
# Processed topics: [1, 2, 4]
# Found text: Text: Storage is a big issue and will continue to grow. It would be fantastic if our municipality could take the lead in this.
# Found topics string: Landscapes and windmills tourism
# Extracted topics: ['Landscapes and windmills tourism']
# Processed topics: [5]
# Finished processing file: individual_annotators_results/RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-36-29_Annotator_5.txt
# Processed file saved to: processed_data\RaR_Emotion_Prompt_CoT_Few_shot_all_annotators_2024-06-03_22-36-29_Annotator_5_processed.txt

# %%
def combine_results(file_paths):
    """
    Combine results from multiple files
    For each text -> topics from each file

    Args:
        file_paths (list): the list of file paths that has been preprocessed
    Returns:
        combined_results (list) : list combined results

    """
    combined_results = defaultdict(list)

    for file_path in file_paths:
        with open(file_path, 'r') as file:
            content = file.read().strip().split("\n\n")
            for entry in content:
                if 'Topics' in entry:
                    try:
                        text_part, label_part = entry.split("{'Topics': ")
                        text = text_part.replace("Text: ", "").strip()
                        topics = "{'Topics': " + label_part.strip()
                        combined_results[text].append(topics)
                    except ValueError:
                        print(f"Skipping entry due to parsing error: {entry}")

    return combined_results

def aggregate_results(combined_results):
    """
    Aggregate the topics results from multiple files using majority vote

    Args:
        combined_results (list): the list of combined results from preprocessed file (for each text -> topics from each file)
    Returns:
        aggregated_results (list) : list of aggregated results using majority vote

    """
    aggregated_results = {}

    for text, topics in combined_results.items():
        all_topics = [topic.strip() for topic_list in topics for topic in topic_list.replace("{'Topics': ", "").replace("}", "").split(',')]
        topic_counts = Counter(all_topics)
        majority_topics = [topic for topic, count in topic_counts.items() if count >= (len(file_paths) / 2)]
        aggregated_results[text] = majority_topics

    return aggregated_results

def save_combined_results(combined_results, output_path):
    """
    Save in a new file the combined results from multiple files
    For each text -> topics from each file

    Args:
        combined_results (list): the list of combined results from preprocessed file (for each text -> topics from each file)
        output_path (str): the output path of the new file

    """
    with open(output_path, 'w') as file:
        for text, topics_list in combined_results.items():
            file.write(f"Text: {text}\n")
            for topics in topics_list:
                file.write(f"{topics}\n")
            file.write("\n")

def save_aggregated_results(aggregated_results, output_path):
    """
    Save the aggregated results

    Args:
        aggregated_results (list) : list of aggregated results using majority vote
        output_path (str): the output path of the new file
    """
    with open(output_path, 'w') as file:
        for text, topics in aggregated_results.items():
            file.write(f"Text: {text}\n")
            file.write(f"Assigned Topics: {', '.join(topics)}\n\n")
# Out:
# aggregated_results/Combined_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_1.txt aggregated_results/Aggregated_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_1.txt
# aggregated_results/Combined_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_2.txt aggregated_results/Aggregated_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_2.txt
# aggregated_results/Combined_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_3.txt aggregated_results/Aggregated_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_3.txt
# aggregated_results/Combined_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_4.txt aggregated_results/Aggregated_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_4.txt
# aggregated_results/Combined_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_5.txt aggregated_results/Aggregated_Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_5.txt

# %%
for annotator_id in range(5):
    output_combined_text_path = 'aggregated_results/Combined_Results_' + method + "_Annotator_"+ str(annotator_id + 1) + '.txt'
    output_aggregated_text_path = 'aggregated_results/Aggregated_Results_' + method + "_Annotator_"+ str(annotator_id + 1) + '.txt'
    file_paths_per_annotator = []
    for fp in file_paths:
        file_paths_per_annotator.append(f"processed_data/{fp.replace('results/', '').replace('.txt', '_Annotator_' + str(annotator_id + 1) +  '_processed.txt')}")

    # Combine the results from the text files into the desired format
    combined_results = combine_results(file_paths_per_annotator)

    # Save the combined results to a text file
    save_combined_results(combined_results, output_combined_text_path)

    # Aggregate the results using majority vote
    aggregated_results = aggregate_results(combined_results)

    # Save the aggregated results to a text file
    save_aggregated_results(aggregated_results, output_aggregated_text_path)

    print(output_combined_text_path, output_aggregated_text_path)

# %%
def load_aggregated_data_csv(annotator_id):
    """
    Load aggregated results in a csv for each annotator

    Args:
        annotator_id (list) : the annotator id
    """
    # Load the provided empty CSV file
    empty_df = pd.read_csv('Empty_data_set.csv', delimiter=';')

    # Define the mapping of labels to column names
    label_to_column = {
        '1': 'Municipality and residents engagement in the energy sector',
        '2': 'Energy storage and supplying energy in The Netherlands',
        '3': 'Wind and solar energy',
        '4': 'Market Determination Dynamics',
        '5': 'Landscapes and windmills tourism',
        '6': 'Hydrogen energy pipeline networks'
    }

    # Initialize a dictionary to store text to index mapping
    text_to_index = {}

    # Map text to their row index in the empty CSV file
    for idx, row in empty_df.iterrows():
        text = row['english'].strip()
        text_to_index[text] = idx

    # Initialize all columns to '0'
    for column in label_to_column.values():
        empty_df[column] = '0'

    # Fill the columns based on the aggregated labels from the Aggregated_Results.txt file
    output_aggregated_text_path = "aggregated_results/Aggregated_Results_"+ method + "_Annotator_"+ str(annotator_id + 1) + '.txt'
    with open(output_aggregated_text_path, 'r') as file:
        content = file.read().strip().split("\n\n")
        for entry in content:
            lines = entry.split("\n")
            if len(lines) < 2:
                continue
            text = lines[0].replace("Text: ", "").strip()
            topics_line = lines[1].replace("Assigned Topics: ", "").strip()
            topics = topics_line.split(", ") if topics_line else []
            if text in text_to_index:
                idx = text_to_index[text]
                for label, column_name in label_to_column.items():
                    if label in topics:
                        empty_df.at[idx, column_name] = '1'

    # Save the filled CSV file
    filled_csv_path_final = 'llm_annotated_data/Results_' + method + "_Annotator_"+ str(annotator_id + 1) + '.csv'
    empty_df.to_csv(filled_csv_path_final, index=False, sep=';')

    print(filled_csv_path_final)
# Out:
# llm_annotated_data/Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_1.csv
# llm_annotated_data/Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_2.csv
# llm_annotated_data/Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_3.csv
# llm_annotated_data/Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_4.csv
# llm_annotated_data/Results_RaR-Few-shot-CoT-Emotion-Prompt_Annotator_5.csv

# %%
for annotator_id in range(number_of_annotators):
    load_aggregated_data_csv(annotator_id)
